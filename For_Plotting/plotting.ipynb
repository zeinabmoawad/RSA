# %%
import socket   
import math     
import csv
import numpy as np
import json
import time
from matplotlib import pyplot as plt

# %%
x = np.linspace(28, 65,(65-28))

# %%
y=[]
file1 = open('Encryption_time_ofAlice.txt', 'r')
count = 0
for line in file1:
    y.append(int(float(line)*(10**3)))
file1.close()
plt.plot(x,y)
# naming the x axis
plt.xlabel('n-size (bits)')
# naming the y axis
plt.ylabel('Time in milli seconds')
  
# giving a title to my graph
plt.title('Encryption_time_ofAlice')
plt.show()

# %%
y=[]
file1 = open('Decryption_time_ofAlice.txt', 'r')
count = 0
for line in file1:
    y.append(int(float(line)*(10**3)))
file1.close()
plt.plot(x,y)
# naming the x axis
plt.xlabel('n-size (bits)')
# naming the y axis
plt.ylabel('Time in milli seconds')
  
# giving a title to my graph
plt.title('Decryption_time_ofAlice')
plt.show()

# %%
y=[]
file1 = open('Encryption_time_ofBob.txt', 'r')
count = 0
for line in file1:
    y.append(int(float(line)*(10**3)))
file1.close()
plt.plot(x,y)
# naming the x axis
plt.xlabel('n-size (bits)')
# naming the y axis
plt.ylabel('Time in milli seconds')
# giving a title to my graph
plt.title('Encryption_time_ofBob')
plt.show()

# %%
y=[]
file1 = open('Decryption_time_ofBob.txt', 'r')
count = 0
for line in file1:
    y.append(int(float(line)*(10**3)))
file1.close()
plt.plot(x,y)
# naming the x axis
plt.xlabel('n-size (bits)')
# naming the y axis
plt.ylabel('Time in milli seconds')
  
# giving a title to my graph
plt.title('Decryption_time_ofBob')
plt.show()

# %%
y=[]
file1 = open('timing.txt', 'r')
count = 0
for line in file1:
    y.append(int(float(line)*(10**3)))
file1.close()
plt.plot(x,y)
# naming the x axis
plt.xlabel('n-size (bits)')
# naming the y axis
plt.ylabel('Time in milli seconds')
  
# giving a title to my graph
plt.title('Attacking_time')
plt.show()
